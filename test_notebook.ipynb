# %%
from utils_dynamic import *

# %%
date = "7Nov"

# %%
listeGroupes, listePassagers = get_config_instance(date)

# %%
listeGroupes
# Out:
# {0: groupe #0,
#  1: groupe #1,
#  2: groupe #2,
#  3: groupe #3,
#  4: groupe #4,
#  5: groupe #5,
#  6: groupe #6,
#  7: groupe #7,
#  8: groupe #8,
#  9: groupe #9,
#  10: groupe #10,
#  11: groupe #11,
#  12: groupe #12,
#  13: groupe #13,
#  14: groupe #14,
#  15: groupe #15,
#  16: groupe #16,
#  17: groupe #17,
#  18: groupe #18,
#  19: groupe #19,
#  20: groupe #20,
#  21: groupe #21,
#  22: groupe #22,
#  23: groupe #23,
#  24: groupe #24,
#  25: groupe #25,
#  26: groupe #26,
#  27: groupe #27,
#  28: groupe #28,
#  29: groupe #29,
#  30: groupe #30,
#  31: groupe #31,
#  32: groupe #32,
#  33: groupe #33,
#  34: groupe #34,
#  35: groupe #35,
#  36: groupe #36,
#  37: groupe #37,
#  38: groupe #38,
#  39: groupe #39,
#  40: groupe #40,
#  41: groupe #41,
#  42: groupe #42,
#  43: groupe #43,
#  44: groupe #44,
#  45: groupe #45,
#  46: groupe #46,
#  47: groupe #47,
#  48: groupe #48,
#  49: groupe #49,
#  50: groupe #50,
#  51: groupe #51,
#  52: groupe #52,
# ...

# %%
listePassagers
# Out:
# [passager # 152 du groupe #0,
#  passager # 153 du groupe #1,
#  passager # 154 du groupe #2,
#  passager # 155 du groupe #3,
#  passager # 156 du groupe #4,
#  passager # 157 du groupe #4,
#  passager # 158 du groupe #5,
#  passager # 159 du groupe #6,
#  passager # 160 du groupe #7,
#  passager # 161 du groupe #7,
#  passager # 162 du groupe #8,
#  passager # 163 du groupe #9,
#  passager # 164 du groupe #10,
#  passager # 165 du groupe #10,
#  passager # 166 du groupe #11,
#  passager # 167 du groupe #12,
#  passager # 168 du groupe #13,
#  passager # 169 du groupe #13,
#  passager # 170 du groupe #14,
#  passager # 171 du groupe #15,
#  passager # 172 du groupe #16,
#  passager # 173 du groupe #16,
#  passager # 174 du groupe #17,
#  passager # 175 du groupe #18,
#  passager # 176 du groupe #18,
#  passager # 177 du groupe #18,
#  passager # 178 du groupe #18,
#  passager # 179 du groupe #19,
#  passager # 180 du groupe #19,
#  passager # 181 du groupe #19,
# ...
